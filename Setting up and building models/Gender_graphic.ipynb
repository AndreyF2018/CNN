# %%
import matplotlib.pyplot as plt

# %%
loss = [0.4117,0.2455,0.1650,0.1313,0.1158,0.0985,0.0899,0.0673,0.0621,
        0.0575,0.048,0.0433,0.0339,0.0358,0.0351,0.0286,0.0341,0.0217,
        0.0279,0.025,0.0227,0.0311,0.0127,0.0287,0.0163,0.0225,0.0257,
        0.0254,0.0169,0.0102]

acc = [0.8169, 0.8996,0.9336,0.9474,0.9529,0.9586,0.9631,0.9760, 0.9771,
       0.9787,0.982,0.9826,0.9869,0.9869,0.9859,0.9887,0.9871,0.9918,
       0.9902,0.9896,0.9902,0.9893,0.9955,0.9887,0.9932,0.9908,0.9920,
       0.9922,0.9939,0.9953 ]

val_loss = [0.2813,0.1554,0.1200,0.1175,0.1123,0.1181,0.123,0.0910,
            0.1015,0.1135,0.1261,0.1058,0.1375,0.1509,0.1366,0.1416,
            0.1576,0.1353,0.2478,0.2586,0.1944,0.1534,0.1766,0.1134,
            0.1868,0.1837,0.2116,0.1945,0.2056,0.2541]

val_acc = [0.9000,0.9337,0.9471,0.9462,0.9548,0.9519,0.9481,0.9615,
           0.9596,0.9538,0.9577,0.9587,0.9596,0.9567,0.9577,0.9606,
           0.9587,0.9596,0.9404,0.9423,0.9567,0.9606,0.9577,0.9596,
           0.9577,0.9577,0.9567,0.9558,0.9490,0.9500]

# %%
epochs = []
for i in range(1, len(loss)+1):
    epochs.append(i)
#График потерь
plt.plot(epochs, loss, label = "train", color = 'b')
plt.plot(epochs, val_loss, label = "valid", color = 'r')
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
#График точности
plt.plot(epochs, acc, label = "train", color = 'b')
plt.plot(epochs, val_acc, label = "valid", color = 'r')
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
# График точности модели
plt.plot(gender_model.history['acc'])
plt.plot(gender_model.history['val_acc'])
plt.title('Gender model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-a97db8e60646> in <module>
#       1 # График точности модели
# ----> 2 plt.plot(gender_model.get_config['acc'])
#       3 plt.plot(gender_model.history['val_acc'])
#       4 plt.title('Gender model accuracy')
#       5 plt.ylabel('accuracy')
#
# TypeError: 'method' object is not subscriptable

# %%
# График оценки loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
