# %%
import matplotlib.pyplot as plt

# %%
loss = [0.9381,0.6368,0.508,0.4089,0.3414,0.3037,0.2605,
        0.2454,0.1992,0.1645,0.1485,0.1302,0.1098,0.0898,
        0.0896,0.0818,0.0568,0.0555,0.0502,0.0404,0.0408,
        0.0323,0.0383,0.0382,0.0242,0.0329,0.0315,0.0262,
        0.0221,0.0216]

acc = [0.5391,0.7300,0.7957,0.833,0.8713,0.8817,0.9078,0.9070,
       0.9235,0.938,0.9465,0.9539,0.9609,0.9665,0.9691,0.9717,
       0.9813,0.9796,0.9861,0.9883,0.9857,0.9913,0.987,0.9848,
       0.9922,0.9891,0.99,0.9922,0.9935,0.9943]

val_loss = [1.0011,0.7972,0.6054,0.4054,0.3849,0.3129,0.3868,
            0.3166,0.2534,0.2971,0.5102,0.2279,0.3129,0.2917,
            0.4361,0.5032,0.3103,0.2645,0.5835,0.2931,0.2895,
            0.3469,0.343,0.3789,0.576,0.7521,0.5460,0.5368,
            0.4609, 0.3411]

val_acc = [0.5403,0.7581,0.7641,0.8407,0.8286,0.879,0.8528,
           0.8589,0.8972,0.875,0.8044,0.9133,0.8911,0.8972,
           0.8548,0.8488,0.8911,0.9073,0.8347,0.9073,0.9012,
           0.8931,0.9073,0.9073,0.875,0.8367,0.8891,0.8851,
           0.8992,0.9194]

# %%
epochs = []
for i in range(1, len(loss)+1):
    epochs.append(i)
#График потерь
plt.plot(epochs, loss, label = "train", color = 'b')
plt.plot(epochs, val_loss, label = "valid", color = 'r')
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
#График точности
plt.plot(epochs, acc, label = "train", color = 'b')
plt.plot(epochs, val_acc, label = "valid", color = 'r')
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()
